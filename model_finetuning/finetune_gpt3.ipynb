# %%
# !pip install --upgrade openai wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ECE1786_dataset/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ECE1786_dataset

# %%
import openai
import os

# %%
# !ls
# Out:
# checkpoints
# final_dataset_suicide.csv
# final_dataset_suicide_test_10_openai.csv
# final_dataset_suicide_test_10_openai_prepared.jsonl
# final_dataset_suicide_test.csv
# final_dataset_suicide_test_huggingface.csv
# final_dataset_suicide_test_openai.csv
# final_dataset_suicide_test_openai_prepared.jsonl
# final_dataset_suicide_train_10_openai.csv
# final_dataset_suicide_train_10_openai_prepared.jsonl
# final_dataset_suicide_train.csv
# final_dataset_suicide_train_huggingface.csv
# final_dataset_suicide_train_openai.csv
# final_dataset_suicide_train_openai_prepared.jsonl
# my_gpt2
# openai_apikey.txt
# safechat-gpt2

# %%
with open("openai_apikey.txt", "r") as fp:
    key = fp.readline().strip()
os.environ["OPENAI_API_KEY"] = key
openai.api_key = key

# %%
key
# Out:
# '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'

# %%
# For binary classification
! openai api fine_tunes.create \
  -t "final_dataset_suicide_train_10_openai_prepared.jsonl" \
  -v "final_dataset_suicide_test_10_openai_prepared.jsonl" \
  -m "ada:ft-university-of-toronto-2022-12-03-14-02-39" \
  --compute_classification_metrics \
  --classification_n_classes 2 \
  --classification_positive_class " suicide" \
  --n_epochs 4
# Out:
# Found potentially duplicated files with name 'final_dataset_suicide_train_10_openai_prepared.jsonl', purpose 'fine-tune' and size 12875740 bytes
# file-z4DSuagvlQ07JvXwvsxXbYbl
# file-2r93L3ZFvBlFVyB6UAzNiDaw
# Enter file ID to reuse an already uploaded file, or an empty string to upload this file anyway: file-z4DSuagvlQ07JvXwvsxXbYbl
# Reusing already uploaded file: file-z4DSuagvlQ07JvXwvsxXbYbl
# Found potentially duplicated files with name 'final_dataset_suicide_test_10_openai_prepared.jsonl', purpose 'fine-tune' and size 3264419 bytes
# file-oWZFRSdbi2nq5k578w33EX12
# Enter file ID to reuse an already uploaded file, or an empty string to upload this file anyway: file-oWZFRSdbi2nq5k578w33EX12
# Reusing already uploaded file: file-oWZFRSdbi2nq5k578w33EX12
# Created fine-tune: ft-RftHAa9c7d8MAXlhn8s1YKiu
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# ...

# %%
# !openai api fine_tunes.follow -i ft-RftHAa9c7d8MAXlhn8s1YKiu
# Out:
# [2022-12-03 23:09:07] Created fine-tune: ft-RftHAa9c7d8MAXlhn8s1YKiu
# [2022-12-03 23:09:10] Fine-tune costs $4.93
# [2022-12-03 23:09:11] Fine-tune enqueued. Queue number: 0
# [2022-12-03 23:09:16] Fine-tune started
# [2022-12-03 23:17:01] Completed epoch 1/4
# [2022-12-03 23:27:48] Completed epoch 2/4
# [2022-12-03 23:38:28] Completed epoch 3/4
# [2022-12-03 23:49:09] Completed epoch 4/4
# [2022-12-03 23:52:58] Uploaded model: ada:ft-university-of-toronto-2022-12-03-23-52-58
# [2022-12-03 23:52:59] Uploaded result file: file-NPEl9EwceTrarTvUsCZabKRm
# [2022-12-03 23:52:59] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m ada:ft-university-of-toronto-2022-12-03-23-52-58 -p <YOUR_PROMPT>

# %%
print(os.getenv('OPENAI_API_KEY'))
# Out:
# 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

# %%
openai.FineTune.list_events(id="ft-RftHAa9c7d8MAXlhn8s1YKiu")
# Out:
# <OpenAIObject list at 0x7fd7cabef900> JSON: {
#   "data": [
#     {
#       "created_at": 1670064422,
#       "level": "info",
#       "message": "Created fine-tune: ft-T0LqRN0DumPyrYBr1mgrn8bf",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670064452,
#       "level": "info",
#       "message": "Fine-tune costs $1.23",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670064453,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 11",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670065298,
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670068240,
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 9",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670073238,
#       "level": "info",
# ...

# %%
# !openai api fine_tunes.list
# Out:
# {
#   "data": [
#     {
#       "created_at": 1668915403,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": null,
#         "learning_rate_multiplier": null,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-79SlD3bsjVg7aLlirkLgW7T2",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-fBcmiAMtOi9yPPjN8WGPZHa0",
#       "result_files": [],
#       "status": "failed",
#       "training_files": [
#         {
#           "bytes": 132529685,
#           "created_at": 1668915403,
#           "filename": "final_dataset_suicide_train_openai_prepared.jsonl",
#           "id": "file-0KwRSPvK2B5SjEWogHLroa0R",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "deleted",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1668915489,
#       "validation_files": []
#     },
#     {
#       "created_at": 1668916050,
# ...

# %%
# !openai api fine_tunes.results -i ft-RftHAa9c7d8MAXlhn8s1YKiu
# Out:
# step,elapsed_tokens,elapsed_examples,training_loss,training_sequence_accuracy,training_token_accuracy,validation_loss,validation_sequence_accuracy,validation_token_accuracy,classification/accuracy,classification/precision,classification/recall,classification/auroc,classification/auprc,classification/f1.0
# 1,14880,32,0.008352853240834327,1.0,1.0,0.005347323875606843,0.8125,0.927710843373494,,,,,,
# 2,45888,64,0.0036118441445939886,0.90625,0.9662921348314607,,,,,,,,,
# 3,96608,96,0.004323985359658378,1.0,1.0,,,,,,,,,
# 4,119680,128,0.006045202744799147,1.0,1.0,,,,,,,,,
# 5,134048,160,0.008766336214739713,1.0,1.0,,,,,,,,,
# 6,158144,192,0.004808580610299219,0.9375,0.9789473684210527,,,,,,,,,
# 7,181728,224,0.00600526945560756,0.96875,0.9782608695652174,,,,,,,,,
# 8,220672,256,0.003558467943837563,0.96875,0.9883720930232558,,,,,,,,,
# 9,243744,288,0.0064062444754889,1.0,1.0,0.003861671005683862,0.9375,0.9775280898876404,,,,,,
# ...

# %%
# !openai wandb sync -i ft-RftHAa9c7d8MAXlhn8s1YKiu
# Out:
# wandb: Currently logged in as: peterzhangjm (safe-chat). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /content/drive/MyDrive/ECE1786_dataset/wandb/run-20221204_005544-ft-RftHAa9c7d8MAXlhn8s1YKiu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ft-RftHAa9c7d8MAXlhn8s1YKiu
# wandb: ⭐️ View project at https://wandb.ai/safe-chat/GPT-3
# wandb: 🚀 View run at https://wandb.ai/safe-chat/GPT-3/runs/ft-RftHAa9c7d8MAXlhn8s1YKiu
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:      classification/accuracy ▁▇▇█
# wandb:         classification/auprc ▁▇██
# wandb:         classification/auroc ▁▇██
# wandb:          classification/f1.0 ▁▇▇█
# wandb:     classification/precision ▁▂█▂
# wandb:        classification/recall ▁▇▇█
# wandb:             elapsed_examples ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# ...

# %% [markdown]
# ## Qualitative analysis

# %%
res = openai.Completion.create(model="ada:ft-university-of-toronto-2022-12-03-23-52-58", prompt="He wants to suicide." + '\n\n###\n\n', max_tokens=1, temperature=0)
res['choices'][0]['text']
# Out:
# ' suicide'

# %%
res = openai.Completion.create(model="ada:ft-university-of-toronto-2022-12-03-23-52-58", prompt="I am happy." + '\n\n###\n\n', max_tokens=1, temperature=0)
res['choices'][0]['text']
# Out:
# ' non'
